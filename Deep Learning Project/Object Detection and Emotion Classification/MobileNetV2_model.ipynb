# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

import tensorflow as tf

import matplotlib.pyplot as plt

import os
# Out:
# /Users/oliverzhou/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
dataset_path = "Data/images"

from tensorflow.keras.preprocessing.image import ImageDataGenerator

data_with_aug = ImageDataGenerator(rotation_range=10,
            rescale = 1.0/255.0, # Normalize
            width_shift_range=0.1, # Simulating the effect of the object being in different positions
            height_shift_range=0.1,
            horizontal_flip=True,
            vertical_flip=False,
            zoom_range=0.1, # simulate the object being at different distances
            shear_range=0.1, # simulating a tilting effect
            brightness_range=[0.8, 1.2], # under different lighting conditions
            fill_mode='nearest',
            validation_split = 0.4) # how to fill in newly created pixels

train_generator = data_with_aug.flow_from_directory(
    dataset_path,
    class_mode="categorical",
    target_size=(96, 96),
    batch_size=16,
    shuffle=True,
    subset="training"
)

validation_generator = data_with_aug.flow_from_directory(
    dataset_path,
    class_mode="categorical",
    target_size=(96, 96),
    batch_size=16,
    subset="validation"
)
# Out:
# Found 9555 images belonging to 4 classes.
# Found 6366 images belonging to 4 classes.

# %% [markdown]
# # MobileNetV2

# %%
from tensorflow.keras.regularizers import l2
# Load the MobileNetV2 model with pretrained weights from ImageNet, excluding the top layers
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(96, 96, 3))

# Add custom top layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu', kernel_regularizer=l2(0.01))(x)
x = BatchNormalization()(x)  # Add batch normalization
x = Dropout(0.3)(x)
x = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(x)
x = BatchNormalization()(x)
x=Dropout(0.1)(x)
predictions = Dense(4, activation='softmax')(x)  # 4 classes for the 4 dog emotions

# Define learning rate scheduler
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',  
    factor=0.2,
    patience=5,
    min_lr=0.00001
)

# Define early stopping
early_stop = EarlyStopping(
    monitor='val_loss',  
    patience=10,
    restore_best_weights=True
)

# %% [markdown]
# # Reasons for Choosing ReduceLROnPlateau
#
# ## Dynamic Learning Rate Adjustment:
#
# ReduceLROnPlateau dynamically adjusts the learning rate during training based on the validation loss. If the validation loss stops improving for a certain number of epochs (patience), it reduces the learning rate by a factor (factor). This adaptability can be helpful in fine-tuning the model as it progresses through training.
#
# ## Stability in Convergence:
#
# By reducing the learning rate when the validation loss stagnates, ReduceLROnPlateau can help stabilize the training process and prevent the model from overshooting or oscillating around the optimal solution.
#
# # Example Use Case
#
# ## Fine-Tuning:
# As the model learns the features of different dog emotions, it may encounter plateaus in the training progress. ReduceLROnPlateau can adjust the learning rate accordingly, allowing the model to navigate through these plateaus more effectively.
#
# ## Preventing Overfitting:
# Dynamically reducing the learning rate based on the validation loss can help prevent overfitting, ensuring that the model generalizes well to unseen data and accurately predicts emotions in real-world scenarios.

# %%
# Define the model
model = Model(inputs=base_model.input, outputs=predictions)

# Freeze the base model layers to prevent them from being trained
for layer in base_model.layers:
    layer.trainable = False

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=30,
    callbacks = [reduce_lr, early_stop]
)
# Out:
# Epoch 1/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 32s 51ms/step - accuracy: 0.3719 - loss: 9.6208 - val_accuracy: 0.4416 - val_loss: 3.8138 - learning_rate: 0.0010
# Epoch 2/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.4503 - loss: 3.0863 - val_accuracy: 0.4466 - val_loss: 1.9312 - learning_rate: 0.0010
# Epoch 3/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.4543 - loss: 1.7815 - val_accuracy: 0.4263 - val_loss: 1.6078 - learning_rate: 0.0010
# Epoch 4/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 31s 51ms/step - accuracy: 0.4676 - loss: 1.5182 - val_accuracy: 0.4500 - val_loss: 1.4930 - learning_rate: 0.0010
# Epoch 5/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - accuracy: 0.4621 - loss: 1.5017 - val_accuracy: 0.4527 - val_loss: 1.4688 - learning_rate: 0.0010
# Epoch 6/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - accuracy: 0.4569 - loss: 1.4639 - val_accuracy: 0.4285 - val_loss: 1.5186 - learning_rate: 0.0010
# Epoch 7/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - accuracy: 0.4553 - loss: 1.4800 - val_accuracy: 0.4603 - val_loss: 1.4584 - learning_rate: 0.0010
# Epoch 8/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 30s 49ms/step - accuracy: 0.4525 - loss: 1.4606 - val_accuracy: 0.4494 - val_loss: 1.5017 - learning_rate: 0.0010
# Epoch 9/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - accuracy: 0.4563 - loss: 1.4785 - val_accuracy: 0.4494 - val_loss: 1.4538 - learning_rate: 0.0010
# Epoch 10/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.4651 - loss: 1.4393 - val_accuracy: 0.4430 - val_loss: 1.4873 - learning_rate: 0.0010
# Epoch 11/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 31s 51ms/step - accuracy: 0.4654 - loss: 1.4294 - val_accuracy: 0.4647 - val_loss: 1.4210 - learning_rate: 0.0010
# Epoch 12/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 30s 49ms/step - accuracy: 0.4712 - loss: 1.4062 - val_accuracy: 0.4651 - val_loss: 1.4283 - learning_rate: 0.0010
# Epoch 13/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.4679 - loss: 1.4134 - val_accuracy: 0.4450 - val_loss: 1.4458 - learning_rate: 0.0010
# Epoch 14/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.4655 - loss: 1.3886 - val_accuracy: 0.4654 - val_loss: 1.3894 - learning_rate: 0.0010
# Epoch 15/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - accuracy: 0.4822 - loss: 1.3732 - val_accuracy: 0.4566 - val_loss: 1.3813 - learning_rate: 0.0010
# Epoch 16/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - accuracy: 0.4794 - loss: 1.3634 - val_accuracy: 0.4505 - val_loss: 1.3945 - learning_rate: 0.0010
# Epoch 17/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - accuracy: 0.4734 - loss: 1.3505 - val_accuracy: 0.4563 - val_loss: 1.3675 - learning_rate: 0.0010
# Epoch 18/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 31s 51ms/step - accuracy: 0.4837 - loss: 1.3295 - val_accuracy: 0.4665 - val_loss: 1.3680 - learning_rate: 0.0010
# Epoch 19/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - accuracy: 0.4795 - loss: 1.3254 - val_accuracy: 0.4667 - val_loss: 1.3350 - learning_rate: 0.0010
# Epoch 20/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - accuracy: 0.4664 - loss: 1.3379 - val_accuracy: 0.4722 - val_loss: 1.3353 - learning_rate: 0.0010
# Epoch 21/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - accuracy: 0.4780 - loss: 1.3259 - val_accuracy: 0.4438 - val_loss: 1.3769 - learning_rate: 0.0010
# Epoch 22/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - accuracy: 0.4813 - loss: 1.3180 - val_accuracy: 0.4599 - val_loss: 1.3365 - learning_rate: 0.0010
# Epoch 23/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - accuracy: 0.4808 - loss: 1.3101 - val_accuracy: 0.4681 - val_loss: 1.3243 - learning_rate: 0.0010
# Epoch 24/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.4776 - loss: 1.3285 - val_accuracy: 0.4565 - val_loss: 1.3431 - learning_rate: 0.0010
# Epoch 25/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 30s 49ms/step - accuracy: 0.4877 - loss: 1.3090 - val_accuracy: 0.4543 - val_loss: 1.3491 - learning_rate: 0.0010
# Epoch 26/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.4768 - loss: 1.3026 - val_accuracy: 0.4588 - val_loss: 1.3456 - learning_rate: 0.0010
# Epoch 27/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 31s 51ms/step - accuracy: 0.4739 - loss: 1.3243 - val_accuracy: 0.4738 - val_loss: 1.3071 - learning_rate: 0.0010
# Epoch 28/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 33s 54ms/step - accuracy: 0.4859 - loss: 1.3094 - val_accuracy: 0.4708 - val_loss: 1.3176 - learning_rate: 0.0010
# Epoch 29/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.4911 - loss: 1.2972 - val_accuracy: 0.4593 - val_loss: 1.3319 - learning_rate: 0.0010
# Epoch 30/30
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.4679 - loss: 1.3235 - val_accuracy: 0.4648 - val_loss: 1.3128 - learning_rate: 0.0010

# %%
# Get training and validation accuracy from history
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# Plot training and validation accuracy
plt.plot(range(1, len(train_accuracy) + 1), train_accuracy, label='Training Accuracy')
plt.plot(range(1, len(val_accuracy) + 1), val_accuracy, label='Validation Accuracy')

# Add labels and title
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# # Performance Metrics

# %%
from sklearn.metrics import classification_report

# Get true labels from the validation generator
y_true = validation_generator.classes

# Get predicted probabilities from the model
y_pred_prob = model.predict(validation_generator)

# Convert predicted probabilities to class labels
y_pred = y_pred_prob.argmax(axis=1)

class_names = list(validation_generator.class_indices.keys())

# Generate classification report
report = classification_report(y_true, y_pred, target_names=class_names)
print(report)
# Out:
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step
#               precision    recall  f1-score   support
#
#        angry       0.00      0.00      0.00       902
#        happy       0.32      0.35      0.33      1913
#      relaxed       0.29      0.27      0.28      1739
#          sad       0.28      0.42      0.34      1812
#
#     accuracy                           0.30      6366
#    macro avg       0.22      0.26      0.24      6366
# weighted avg       0.25      0.30      0.27      6366

# %%
import seaborn as sns
import pandas as pd

# Plot distribution of true labels
true_label_counts = pd.Series(y_true).value_counts()
true_label_counts.index = [class_names[i] for i in true_label_counts.index]

plt.figure(figsize=(10, 5))
sns.barplot(x=true_label_counts.index, y=true_label_counts.values)
plt.title('Distribution of True Labels')
plt.xlabel('Classes')
plt.ylabel('Frequency')
plt.show()

# Plot distribution of predicted labels
pred_label_counts = pd.Series(y_pred).value_counts()
pred_label_counts.index = [class_names[i] for i in pred_label_counts.index]

plt.figure(figsize=(10, 5))
sns.barplot(x=pred_label_counts.index, y=pred_label_counts.values)
plt.title('Distribution of Predicted Labels')
plt.xlabel('Classes')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## ROC/AUC

# %%
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import label_binarize

# Binarize the labels for ROC AUC
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

roc_auc = roc_auc_score(y_true_binarized, y_pred_prob, multi_class='ovr')
print(f'ROC AUC: {roc_auc}')
# Out:
# ROC AUC: 0.5060016809449281

# %% [markdown]
# ## Precision, Recall, F-1 Score

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
# Out:
# Precision: 0.25474133504435
# Recall: 0.29516179704681117
# F1 Score: 0.27089946094690154

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Generate confusion matrix
cm = confusion_matrix(y_true, y_pred)
class_names = list(validation_generator.class_indices.keys())

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # Accuracy

# %%
from sklearn.metrics import accuracy_score

# Compute accuracy
accuracy = accuracy_score(y_true, y_pred)
print(f'Overall Accuracy: {accuracy}')
# Out:
# Overall Accuracy: 0.29516179704681117
